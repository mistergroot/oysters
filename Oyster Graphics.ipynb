# %%
import csv
import pandas as pd

# %%
class MyColorFunctor():
  def __init__(self,frequencies):
    self.frequencies = frequencies

  def __call__(self,word,font_size,position,orientation,random_state=None,**kwargs):
    return "hsl(%d, %d%%, %d%%)" % (212, 100, self.frequencies[word]/6.92)

# %%
oysters = csv.reader(open('project-2.csv', 'r',newline='\n'))
data = {}
for k,v in oysters:
    data[k] = int(v)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

#Generating wordcloud. Relative scaling value is to adjust the importance of a frequency word.
#See documentation: https://github.com/amueller/word_cloud/blob/master/wordcloud/wordcloud.py
wordcloud = WordCloud(font_path="/usr/share/fonts/truetype/nanum/NanumGothic.ttf",
                      width=1920,
                      height=1080, 
                      max_words=1628, 
                      background_color="black",
                      relative_scaling=1,
                      normalize_plurals=False,
                      color_func=MyColorFunctor(data)).generate_from_frequencies(data).to_file("index.png")

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
oysters2 = csv.reader(open('Researchers-1.csv', 'r',newline='\n'))
researchers = {}
for k,v in oysters2:
    researchers[k] = int(v)

# %%
wordcloud = WordCloud(font_path="/usr/share/fonts/truetype/nanum/NanumGothic.ttf",
                      width=1920,
                      height=1080, 
                      max_words=1628, 
                      background_color="black",
                      relative_scaling=1,
                      normalize_plurals=False,
                      color_func=MyColorFunctor(researchers)).generate_from_frequencies(researchers).to_file("researchers-1.png")

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
oysters3 = csv.reader(open('TNC.csv', 'r',newline='\n'))
TNC = {}
for k,v in oysters3:
    TNC[k] = int(v)

# %%
wordcloud = WordCloud(font_path="/usr/share/fonts/truetype/nanum/NanumGothic.ttf",
                      width=1920,
                      height=1080, 
                      max_words=1628, 
                      background_color="black",
                      relative_scaling=1,
                      normalize_plurals=False,
                      color_func=MyColorFunctor(TNC)).generate_from_frequencies(TNC).to_file("TNC.png")

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
oysters4 = csv.reader(open('Government.csv', 'r',newline='\n'))
combogov = {}
for k,v in oysters4:
    combogov[k] = int(v)

# %%
wordcloud = WordCloud(font_path="/usr/share/fonts/truetype/nanum/NanumGothic.ttf",
                      width=1920,
                      height=1080, 
                      max_words=1628, 
                      background_color="black",
                      relative_scaling=1,
                      normalize_plurals=False,
                      color_func=MyColorFunctor(combogov)).generate_from_frequencies(combogov).to_file("Government.png")

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
oysters5 = csv.reader(open('NGO.csv', 'r',newline='\n'))
combongo = {}
for k,v in oysters5:
    combongo[k] = int(v)

# %%
wordcloud = WordCloud(font_path="/usr/share/fonts/truetype/nanum/NanumGothic.ttf",
                      width=1920,
                      height=1080, 
                      max_words=1628, 
                      background_color="black",
                      relative_scaling=1,
                      normalize_plurals=False,
                      color_func=MyColorFunctor(combongo)).generate_from_frequencies(combongo).to_file("NGO.png")

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
