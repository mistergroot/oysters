# %%
def my_tf_color_func(dictionary):
  def my_tf_color_func_inner(word, 
                             font_size, 
                             position, 
                             orientation, 
                             random_state=None, **kwargs):
    return "hsl(%d, 80%%, 50%%)" % (360 * dictionary[word])
  return my_tf_color_func_inner

# %%
import csv
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

reader = csv.reader(open('Untitled1.csv', 'r',newline='\n'))
d = {}
for k,v in reader:
    d[k] = int(v)

#Generating wordcloud. Relative scaling value is to adjust the importance of a frequency word.
#See documentation: https://github.com/amueller/word_cloud/blob/master/wordcloud/wordcloud.py
wordcloud = WordCloud(width=2000,
                      height=1080, 
                      max_words=1628, 
                      colormap="GnBu",
                      background_color="black",
                      relative_scaling=1,
                      normalize_plurals=False,
                      color_func=my_tf_color_func(butt[1])).generate_from_frequencies(d).to_file("index.png")

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-1c9d52499e4f> in <module>()
#       7 d = {}
#       8 for k,v in reader:
# ----> 9     d[k] = int(v)
#      10
#      11 #Generating wordcloud. Relative scaling value is to adjust the importance of a frequency word.
#
# ValueError: invalid literal for int() with base 10: 'Frequency'

# %%
butt=pd.read_csv("Untitled1.csv", header=None)

# %%
butt[1]
# Out:
# 0     791
# 1     683
# 2     632
# 3     537
# 4     524
# 5     365
# 6     360
# 7     300
# 8     299
# 9     299
# 10    285
# 11    265
# 12    200
# 13    199
# 14    167
# 15    167
# 16     97
# 17     94
# 18     60
# 19      3
# 20      3
# Name: 1, dtype: int64

# %%
butt
# Out:
#                                   0    1
# 0                  State Government  791
# 1                           Habitat  683
# 2                       Aquaculture  632
# 3                     Water Quality  537
# 4                  Reef Restoration  524
# 5                              Jobs  365
# 6                Food and Fisheries  360
# 7   Fish Recruitment and Settlement  300
# 8                    Oyster Disease  299
# 9                            Cultch  299
# 10       Oyster Spat and Settlement  285
# 11                        Fishermen  265
# 12                 Nutrient Cycling  200
# 13                      Oyster Seed  199
# 14                   Oyster Farmers  167
# 15                     Biodiversity  167
# 16             Shoreline Protection   97
# 17               Recreational Users   94
# 18                        Educators   60
# 19                      Restaurants    3
# 20                 Local Government    3
