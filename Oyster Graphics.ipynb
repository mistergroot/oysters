# %%
class MyColorFunctor():
  def __init__(self,frequencies):
    self.frequencies = frequencies

  def __call__(self,word,font_size,position,orientation,random_state=None,**kwargs):
    return "hsl(%d, %d%%, %d%%)" % (212, 100, self.frequencies[word]/7.91)

# %%
oysters = csv.reader(open('project-2.csv', 'r',newline='\n'))
data = {}
for k,v in oysters:
    data[k] = int(v)

# %%
data
# Out:
# {'State Govt': 791,
#  'Habitat': 683,
#  'Aquaculture': 632,
#  'Water Quality': 537,
#  'Reef Restoration': 524,
#  'Jobs': 365,
#  'Food and Fisheries': 360,
#  'Fish Recruitment & Settlement': 300,
#  'Oyster Disease': 299,
#  'Cultch': 299,
#  'Oyster Spat & Settlement': 285,
#  'Fishermen': 265,
#  'Nutrient Cycling': 200,
#  'Oyster Seed': 199,
#  'Oyster Farmers': 167,
#  'Biodiversity': 167,
#  'Shoreline Protection': 97,
#  'Recreational Users': 94,
#  'Educators': 60,
#  'Restaurants': 3,
#  'Local Government': 3}

# %%
import csv
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

#Generating wordcloud. Relative scaling value is to adjust the importance of a frequency word.
#See documentation: https://github.com/amueller/word_cloud/blob/master/wordcloud/wordcloud.py
wordcloud = WordCloud(width=1920,
                      height=1080, 
                      max_words=1628, 
                      background_color="black",
                      relative_scaling=1,
                      normalize_plurals=False,
                      color_func=MyColorFunctor(data)).generate_from_frequencies(data).to_file("index.png")

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
